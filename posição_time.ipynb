# %%
import pandas as pd
import warnings

# %%
pd.set_option('display.max_columns', None)

# %%
warnings.filterwarnings(action='ignore')

# %%
df=pd.read_csv('soccerDB4.csv')

# %%
temp=df[1139:]

# %%
temp=temp.drop(columns='Unnamed: 0')

# %%
temp=temp.reset_index()

# %%
temp=temp.drop(columns='index')

# %%
#for n in games:
    ['round'][contador]
        if ['round'][contador] > contador_rodada:
            
            
for n in range():
    temp['round'][contador] 
    temp['ht_previuos_classification']=['ht_current_classification'] in ['round'][contador-1]
    
    temp[(temp['ht_current_classification'][contador] in temp['round'] > temp['ht_current_classification'][contador] in temp[temp['round']-1])]
    
    
    if temp['ht_current_classification'['round']]['contador'] > temp[['ht_current_classification',['round'][-1]]]   
    
    temp['ht_current_classification']['contador'] 
    
    temp['round'][contador]
    temp['home_team'][contador]

    temp['away_team']
# Out:
#   File "<ipython-input-53-9cf5b6a1302d>", line 2
#     temp[(temp['ht_current_classification'][contador] in temp['round'] > temp['ht_current_classification'][contador] in temp[temp['round']-1])
#     ^
# IndentationError: unexpected indent

# %%
temp.groupby(['round','home_team','ht_current_classification']).count()
# Out:
#                                                a_Ataques  a_Ataques perigosos  \
# round home_team     ht_current_classification
# 1     América MG    18                                 1                    1
#                     20                                 1                    1
#       Atlético MG   4                                  1                    1
#                     5                                  1                    1
#       Atlético PR   7                                  1                    1
#                     8                                  1                    1
#                     10                                 1                    1
#       Avaí          17                                 1                    1
#                     18                                 1                    1
#       Bahia         12                                 1                    1
# ...

# %%
times2=times.drop(columns=times[0:])#times=

# %%
times2=times2.reset_index()

# %%
for times2
# Out:
#       round  ht_current_classification      home_team
# 0         1                          1    Corinthians
# 1         1                          1       Cruzeiro
# 2         1                          1      Palmeiras
# 3         1                          2         Grêmio
# 4         1                          2      Palmeiras
# 5         1                          2      São Paulo
# 6         1                          3       Flamengo
# 7         1                          3         Grêmio
# 8         1                          3  Internacional
# 9         1                          4    Atlético MG
# 10        1                          4         Grêmio
# 11        1                          4      São Paulo
# 12        1                          5    Atlético MG
# 13        1                          5       Botafogo
# 14        1                          5       Cruzeiro
# 15        1                          5      São Paulo
# ...
