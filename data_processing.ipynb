# %%
import pandas as pd
import numpy as np
import time
from tqdm import tqdm

# %%
df = pd.read_pickle('./data/soccerDBNew2_n.pkl')

# %%
df['result'] = np.nan

# %%
def getResults(df): 
    for i in tqdm(range(len(df))):
        if df.home_team_score[i] > df.away_team_score[i]:
            df['result'][i] = 'win'
        elif df.home_team_score[i] == df.away_team_score[i]:
            df['result'][i] = 'draw'
        else:
            df['result'][i] = 'lose'
    return df

# %%
# %%time
df = getResults(df)
# Out:
#   0%|          | 0/3419 [00:00<?, ?it/s]/home/renan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /home/renan/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# /home/renan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
def to_integer(dt_time):
    return dt_time.dt.day + 100*dt_time.dt.month + 10000*dt_time.dt.year

# %%
# %%time
df.datetime = to_integer(df.datetime)
# Out:
# CPU times: user 8.43 ms, sys: 3 µs, total: 8.43 ms
# Wall time: 7.94 ms

# %%
df['home_player_1'] = np.nan
df['home_player_2'] = np.nan
df['home_player_3'] = np.nan
df['home_player_4'] = np.nan
df['home_player_5'] = np.nan
df['home_player_6'] = np.nan
df['home_player_7'] = np.nan
df['home_player_8'] = np.nan
df['home_player_9'] = np.nan
df['home_player_10'] = np.nan
df['home_player_11'] = np.nan
df['away_player_1'] = np.nan
df['away_player_2'] = np.nan
df['away_player_3'] = np.nan
df['away_player_4'] = np.nan
df['away_player_5'] = np.nan
df['away_player_6'] = np.nan
df['away_player_7'] = np.nan
df['away_player_8'] = np.nan
df['away_player_9'] = np.nan
df['away_player_10'] = np.nan
df['away_player_11'] = np.nan

# %%
players_list = ['home_player_1',
'home_player_2',
'home_player_3',
'home_player_4',
'home_player_5',
'home_player_6',
'home_player_7',
'home_player_8',
'home_player_9',
'home_player_10',
'home_player_11',
'away_player_1',
'away_player_2',
'away_player_3',
'away_player_4',
'away_player_5',
'away_player_6',
'away_player_7',
'away_player_8',
'away_player_9',
'away_player_10',
'away_player_11']

# %%
df['home_lineup'] = np.nan

# %%
df['away_lineup'] = np.nan

# %%
def splitLineupList(df):
    contx=0
    for x in tqdm(df.lineupList):
        df.home_lineup[contx] = x[0]
        df.away_lineup[contx] = x[1]
        contx += 1
    return df

# %%
# %%time
df = splitLineupList(df)
# Out:
#   0%|          | 0/3419 [00:00<?, ?it/s]/home/renan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /home/renan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# 100%|██████████| 3419/3419 [04:38<00:00, 12.82it/s]
# CPU times: user 4min 36s, sys: 1.43 s, total: 4min 38s
# Wall time: 4min 38s

# %%
def splitPlayers(df):
    for m in tqdm(range(len(df))):
        for n in range(len(df.home_lineup[m])):
            df[players_list[n]][m] = df.home_lineup[m][n]

# %%
# %%time
df = splitPlayers(df)
# Out:
#   0%|          | 0/3419 [00:00<?, ?it/s]/home/renan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# 100%|██████████| 3419/3419 [24:07<00:00,  2.36it/s]
# CPU times: user 24min 6s, sys: 3.47 s, total: 24min 10s
# Wall time: 24min 7s

# %%
df.to_pickle('./data/soccerDB_broken.pkl')

# %%
players_list[11:]
# Out:
# ['away_player_1',
#  'away_player_2',
#  'away_player_3',
#  'away_player_4',
#  'away_player_5',
#  'away_player_6',
#  'away_player_7',
#  'away_player_8',
#  'away_player_9',
#  'away_player_10',
#  'away_player_11']

# %%
for n in range(11,22):
    print(players_list[n])
# Out:
# away_player_1
# away_player_2
# away_player_3
# away_player_4
# away_player_5
# away_player_6
# away_player_7
# away_player_8
# away_player_9
# away_player_10
# away_player_11

# %%
def splitPlayersAway(df):
    for m in tqdm(range(len(df))):
        cont=0
        for n in range(11,22):
            df[players_list[n]][m] = df.home_lineup[m][cont]
            cont+=1

# %%
# %%time
df = splitPlayersAway(df)
# Out:
#   0%|          | 0/3419 [00:00<?, ?it/s]/home/renan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /home/renan/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
#  56%|█████▋    | 1924/3419 [31:45<26:34,  1.07s/it]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <timed exec> in <module>
#
# <ipython-input-44-6f705c653eb1> in splitPlayersAway(df)
# ...

# %%
# Out:
#            home_team       away_team home_team_score away_team_score  \
# 0          Palmeiras         Vitória               1               0
# 1      Internacional        Cruzeiro               1               2
# 2           Flamengo       São Paulo               1               1
# 3        Atlético GO          Grêmio               0               0
# 4        Atlético MG           Vasco               2               1
# 5           Botafogo          Santos               3               3
# 6        Corinthians     Atlético PR               2               1
# 7     Grêmio Barueri     Atlético MG               4               0
# 8              Ceará      Fluminense               1               0
# 9            Guarani           Goiás               1               0
# 10        Fluminense     Atlético GO               1               0
# 11              Avaí  Grêmio Barueri               6               1
# 12           Vitória        Flamengo               1               1
# ...
